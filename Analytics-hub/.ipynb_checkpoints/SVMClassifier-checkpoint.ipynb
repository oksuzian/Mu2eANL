# %%
import sys
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import utils
from sklearn import svm, metrics

# %%
path_to_files = "test_load/" 
dfCRY5 = pd.read_hdf(path_to_files + "CRY5lo.h5").query('(lyield==17000)')

# %%
var_dict = utils.getVarList('allCRY5')
var_dict
# Out:
# {'crvinfo_x': [-8000, 1000],
#  'crvinfo_y': [0, 3500],
#  'crvinfo_z': [-5000, 20000],
#  'de_nhits': [0, 100],
#  'ue_nhits': [0, 100],
#  'dequal_TrkPID': [-1.1, 1.1],
#  'dequal_TrkQual': [-0.1, 1.1],
#  'deent_td': [0, 3],
#  'deent_d0': [-500, 500],
#  'crvinfo_PEs': [-1, 1000],
#  'crvinfo_dT': [-200, 100],
#  'deent_mom': [50, 200]}

# %%
dfCRY5.query('abs(demcpri_pdg)==13')
# Out:
#         evtinfo_eventid  evtinfo_subrunid  evtinfomc_nprotons  de_status  \
# 0                259832                 0                   1          2
# 1                263977                 0                   1          1
# 2                 62701                 6                   1          1
# 3                117858                 6                   1          2
# 4                430037                 6                   1          2
# ...                 ...               ...                 ...        ...
# 204812           314852             93540                   1          1
# 204813           312779             93574                   1          1
# 204814           389678             93574                   1          1
# 204815           470506             93633                   1          1
# 204816           244798             93897                   1          1
#
#         de_pdg  de_nhits        de_t0    deent_d0  deent_maxr  deent_td  ...  \
# 0          -11        57  1265.649170    7.341033 -608.452454  0.332109  ...
# 1          -11        40   584.103760 -159.690765 -642.126587  0.891969  ...
# 2          -11        23  1011.072632  115.154976 -589.048462  0.843411  ...
# 3          -11        33   614.504211  -29.631735 -527.721375  0.474046  ...
# 4          -11        43   915.917480   41.484543 -575.115723  0.331220  ...
# ...        ...       ...          ...         ...         ...       ...  ...
# 204812     -11        31  1472.962158   35.365593 -472.527191  0.695598  ...
# 204813     -11        29  1355.218750 -118.626007 -490.861572  1.121098  ...
# 204814     -11        47  1511.505493 -178.715103 -610.779358  1.032714  ...
# 204815     -11        31  1302.996216   71.978882 -484.013489  0.609513  ...
# 204816     -11        48  1346.637451   97.530266 -623.329163  0.374294  ...
#
#         crvsummarymc_crvSectorType  crvsummarymc_pdgId  dequal_TrkQual  \
# 0                                3                 -13        0.786401
# 1                                3                  13        0.061298
# 2                                3                  13        0.003386
# 3                                3                 -13        0.000584
# 4                                3                 -13        0.129571
# ...                            ...                 ...             ...
# 204812                           3                 -13        0.984643
# 204813                           3                 -13        0.975737
# 204814                           3                 -13        0.999926
# 204815                           3                  13        0.238360
# 204816                           3                 -13        0.996633
#
#         dequal_TrkPID   deent_mom   demcpri_mom  is_high  lyield  \
# 0           -1.000000   98.400986   1907.103149        0   17000
# 1            0.999894   98.037033   1220.846313        0   17000
# 2           -1.000000  139.704849   1553.367676        0   17000
# 3           -1.000000   83.593147   1500.012451        0   17000
# 4           -1.000000   98.503738   1225.212280        0   17000
# ...               ...         ...           ...      ...     ...
# 204812      -1.000000   93.823776   1670.135742        0   17000
# 204813      -1.000000   84.803764   2392.837891        0   17000
# 204814       0.999998   94.191269  12817.048828        0   17000
# 204815      -1.000000   98.744446   1545.615112        0   17000
# 204816      -1.000000  116.725616   2009.012329        0   17000
#
#         debestcrv_dT  debestcrv_dTe
# 0        -114.164551     -26.314575
# 1          15.189270     115.589294
# 2          21.886719     109.736816
# 3        -110.450562     -22.600525
# 4        -114.692017     -26.842041
# ...              ...            ...
# 204812   -123.203857     -35.353882
# 204813    -47.784424      40.065674
# 204814    -20.267822      67.582275
# 204815    -22.882690      52.417236
# 204816   -105.952637      -5.552612
#
# [204063 rows x 79 columns]

# %%
dfCRY5.query('abs(demcpri_pdg)==13 & de_t0 > 600 & debestcrv_timeWindowStart==0')
# Out:
#         evtinfo_eventid  evtinfo_subrunid  evtinfomc_nprotons  de_status  \
# 38               227186             17257                   1          1
# 45                93976             17884                   1          1
# 86               401195             20360                   1          1
# 87               495281             20360                   1          2
# 89               174577             20439                   1          1
# ...                 ...               ...                 ...        ...
# 204426           369479             63194                   1          1
# 204480           474583             67833                   1          1
# 204505            72067             80708                   1          1
# 204615           223335             51130                   1          1
# 204617           362495             51130                   1          1
#
#         de_pdg  de_nhits        de_t0    deent_d0  deent_maxr  deent_td  ...  \
# 38         -11        29  1231.534912 -144.774490 -494.856567  1.376695  ...
# 45         -11        33  1375.597168  -34.306904 -517.035278  1.102262  ...
# 86         -11        42   946.415466 -129.966675 -520.661377  1.516311  ...
# 87         -11        31   985.809814  -48.224419 -533.997375  0.925990  ...
# 89         -11        57  1429.897705 -181.730774 -624.551392  1.180955  ...
# ...        ...       ...          ...         ...         ...       ...  ...
# 204426     -11        60   742.896973 -173.736511 -604.722778  1.111427  ...
# 204480     -11        39  1124.891235 -147.802689 -538.433899  1.025878  ...
# 204505     -11        36  1073.234985  -97.610382 -501.032379  0.889602  ...
# 204615     -11        43   635.364624  -91.120743 -553.530273  0.917258  ...
# 204617     -11        19  1609.126221  -76.723915 -452.818176  0.952273  ...
#
#         crvsummarymc_crvSectorType  crvsummarymc_pdgId  dequal_TrkQual  \
# 38                              -1              -99999        0.998201
# 45                              -1              -99999        0.836486
# 86                              -1              -99999        0.998941
# 87                              -1              -99999        0.981859
# 89                               4                 -13        0.999818
# ...                            ...                 ...             ...
# 204426                           2                 -13        0.997324
# 204480                          -1              -99999        0.997341
# 204505                           3                  13        0.901272
# 204615                          -1              -99999        0.993385
# 204617                          -1              -99999        0.788732
#
#         dequal_TrkPID   deent_mom  demcpri_mom  is_high  lyield  debestcrv_dT  \
# 38          -1.000000   90.335991  8504.970703        0   17000  -1231.534912
# 45          -1.000000  108.951370  3258.206787        0   17000  -1375.597168
# 86           0.999875  107.618423  7068.933105        0   17000   -946.415466
# 87          -1.000000  100.400917  7068.933105        0   17000   -985.809814
# 89           0.999645  103.918823  5459.991699        0   17000  -1429.897705
# ...               ...         ...          ...      ...     ...           ...
# 204426      -1.000000   97.717697  7582.655273        0   17000   -742.896973
# 204480      -1.000000   84.868317  7803.124512        0   17000  -1124.891235
# 204505      -1.000000   81.884117  9719.473633        0   17000  -1073.234985
# 204615      -1.000000   95.157135  8067.059082        0   17000   -635.364624
# 204617      -1.000000   78.758400  7863.878906        0   17000  -1609.126221
#
#         debestcrv_dTe
# 38       -1231.534912
# 45       -1375.597168
# 86        -946.415466
# 87        -985.809814
# 89       -1429.897705
# ...               ...
# 204426    -742.896973
# 204480   -1124.891235
# 204505   -1073.234985
# 204615    -635.364624
# 204617   -1609.126221
#
# [2514 rows x 79 columns]

# %%
1.2215088282504012e-05
1838  /99.4E6
# Out:
# 1.8490945674044265e-05

# %%
1.2215088282504012e-05/6.338028169014085e-06
# Out:
# 1.9272694845728553

# %%
0.0001130872124130551/1.8490945674044265e-05
# Out:
# 6.115815513524308

# %%
ndf = dfCRY5.query('abs(demcpri_pdg)==13 & de_t0 > 600 & debestcrv_timeWindowStart==0')
for label in ndf.columns:
    if label not in var_dict or "crvinfo" in label:
        ndf = ndf.drop(columns=label)
muon_df = ndf

# %%
ndf = dfCRY5.query('demcpri_pdg==2112 & de_t0 > 600 & debestcrv_timeWindowStart==0')
for label in ndf.columns:
    if label not in var_dict or "crvinfo" in label:
        ndf = ndf.drop(columns=label)
neutron_df = ndf

# %%
muon_df.columns
# Out:
# Index(['de_nhits', 'deent_d0', 'deent_td', 'ue_nhits', 'dequal_TrkPID',
#        'dequal_TrkQual', 'deent_mom'],
#       dtype='object')

# %%
neutron_data = neutron_df.to_numpy()
#muon_data = np.take(muon_df.to_numpy(), np.random.choice(len(muon_df), len(neutron_df)), axis=0)
muon_data = muon_df.to_numpy()

# %%
Y_data = np.append(np.zeros(len(muon_data),dtype=int),np.ones(len(neutron_data), dtype=int))  # 0 - muon, 1 - neutron
X_data = np.append(muon_data, neutron_data, axis = 0)
AData = np.append(X_data,Y_data.reshape(len(muon_data) + len(neutron_data), 1), axis = 1)
np.random.shuffle(AData)
X_data, Y_data = AData[:,:-1], AData[:,-1]
Y_data = np.array([int(x) for x in Y_data])

# %%
n_v = int(len(X_data) * 0.2)
n_tr = len(X_data) - n_v

# %%
def get_my_data(num_training=n_tr, num_validation=n_v, num_test=0):

    X_train, y_train = X_data, Y_data
        
    # Сэмплируем из полного набора данных
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]

    return X_train, y_train, X_val, y_val


# Вызываем функцию чтобы получить данные.
X_train, y_train, X_val, y_val = get_my_data()
print('Train data shape: ', X_train.shape)
print('Train label shape: ', y_train.shape)
print('Val data shape: ', X_val.shape)
print('Val label shape:  ', y_val.shape)
# Out:
# Train data shape:  (1975, 7)
# Train label shape:  (1975,)
# Val data shape:  (493, 7)
# Val label shape:   (493,)

# %%
clf = svm.SVC(probability=True)
clf.fit(X_train, y_train)
# Out:
# SVC(probability=True)

# %%
proba = clf.predict_proba(X_val)
y_score = [ x[1] for x in proba]
fpr, tpr, thresholds = metrics.roc_curve(y_val.flatten(), y_score)

# %%
sign_ar = np.append(X_val, proba[:,1].reshape(len(proba),1), axis=1)
sign_ar = np.append(sign_ar, y_val.reshape(len(proba),1), axis=1)
sign_ar = np.append(sign_ar, np.zeros(len(proba),dtype=int).reshape(len(proba),1), axis=1)

# %%
sign_df = pd.DataFrame(sign_ar, columns = [*muon_df.columns,'neutronicity','is_neutron','is_high'])

# %%
# fpr1, tpr1, thresholds1 = fpr, tpr, thresholds

# %%
plt.figure()
# plt.plot(fpr1, tpr1, color="darkorange", label="Nmu = Nn")
plt.plot(fpr, tpr, color="red", label="All data")
plt.plot([0, 1], [0, 1], color="navy", linestyle="--")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver operating characteristic")
plt.legend(loc="lower right")
plt.show()

# %%
#neutronicity

# %%
import cuts
import math

# %%
neve_extmom = len(dfCRY5.query(cuts.cut_extmom))
neve_physmom = len(dfCRY5.query(cuts.cut_phymom))
mom_scale = neve_extmom/neve_physmom
print('Momentum scale: %2.1f'% mom_scale)
ave, err, _, _, _, _ = utils.getNormBackground(dfCRY5, 'abs(demcpri_pdg)==13', mom_scale, lotime=cuts.CRY5_LT_LO, hitime=cuts.CRY5_LT_HI)
print('Muon background: %2.3f +/- %2.3f'%(ave*1.2, err*np.sqrt(1.2)))

ave, err, _, _, _, _ = utils.getNormBackground(dfCRY5, 'demcpri_pdg==2112', mom_scale, lotime=cuts.CRY5_LT_LO, hitime=cuts.CRY5_LT_HI)
print('Neutron background: %2.3f +/- %2.3f'%(ave*1.2, err*np.sqrt(1.2)))
# Out:
# Momentum scale: 46.0
# Muon background: 255.506 +/- 0.440
# Neutron background: 0.719 +/- 0.023

# %%
for pa in np.arange(0.2, 1.6, 0.1):
    try:
        nback = utils.getNormBackground(dfCRY5,'demcpri_pdg==2112 & de_t0 > 600 & debestcrv_timeWindowStart==0 & deent_td < %f' % (pa), 1, lotime=cuts.CRY5_LT_LO, hitime=cuts.CRY5_LT_HI)[0]
        mback = utils.getNormBackground(dfCRY5,'abs(demcpri_pdg)==13 & de_t0 > 600 & debestcrv_timeWindowStart==0 & deent_td < %f' % (pa),1, lotime=cuts.CRY5_LT_LO, hitime=cuts.CRY5_LT_HI)[0]
        print('%f \t %f' % (pa, nback / math.sqrt(mback)))
    except:
        print('\t division by zero : %f' % pa)
# Out:
# 	 division by zero : 0.200000
# 	 division by zero : 0.300000
# 0.400000 	 0.705173
# 0.500000 	 2.227520
# 0.600000 	 4.004642
# 0.700000 	 4.038667
# 0.800000 	 4.046265
# 0.900000 	 4.044426
# 1.000000 	 4.008892
# 1.100000 	 3.622775
# 1.200000 	 3.359773
# 1.300000 	 3.120249
# 1.400000 	 2.999718
# 1.500000 	 2.904303

# %%
for prob in np.arange(0.1, 1.1, 0.05):
    try:
        nback = utils.getNormBackground(sign_df,'is_neutron==1 &  neutronicity > %f' % (prob), 1, lotime=cuts.CRY5_LT_LO*0.2, hitime=cuts.CRY5_LT_HI)[0]
        mback = utils.getNormBackground(sign_df,'is_neutron==0 &  neutronicity > %f' % (prob),1, lotime=cuts.CRY5_LT_LO*0.2, hitime=cuts.CRY5_LT_HI)[0]
        print('%f \t %f' % (prob, nback / math.sqrt(mback)))
    except:
        print('\t division by zero : %f' % prob)
# Out:
# 0.100000 	 1.831857
# 0.150000 	 2.106061
# 0.200000 	 2.609680
# 0.250000 	 3.034294
# 0.300000 	 3.917997
# 0.350000 	 2.711710
# 0.400000 	 3.539942
# 0.450000 	 2.949951
# 0.500000 	 3.337489
# 0.550000 	 2.920303
# 0.600000 	 2.503117
# 0.650000 	 1.668745
# 0.700000 	 1.251558
# 0.750000 	 1.251558
# 0.800000 	 0.417186
# 	 division by zero : 0.850000
# 	 division by zero : 0.900000
# 	 division by zero : 0.950000
# 	 division by zero : 1.000000
# 	 division by zero : 1.050000

# %%
sign_df
# Out:
#      de_nhits    deent_d0  deent_td  ue_nhits  dequal_TrkPID  dequal_TrkQual  \
# 0        59.0   91.786224  1.049798      -1.0      -1.000000        0.864123
# 1        54.0  134.717926  0.591877      49.0      -1.000000        0.310484
# 2        34.0  177.176315  1.753880      -1.0      -1.000000        0.992168
# 3        48.0   14.179731  1.002204      -1.0       0.999712        0.999463
# 4        49.0   45.256378  0.923598      -1.0       0.999899        0.999371
# ..        ...         ...       ...       ...            ...             ...
# 488      23.0    3.058052  1.298054      -1.0      -1.000000        0.821657
# 489      15.0    7.807498  0.770128      52.0      -1.000000        0.001460
# 490      51.0  158.909531  0.979289      -1.0       0.999630        0.999597
# 491      31.0  121.650070  1.384833      -1.0      -1.000000        0.735384
# 492      53.0  -24.113632  0.619039      46.0      -1.000000        0.999481
#
#       deent_mom  neutronicity  is_neutron  is_high
# 0    117.600731      0.255863         0.0      0.0
# 1     74.423477      0.236408         0.0      0.0
# 2    102.875168      0.196069         0.0      0.0
# 3    140.088684      0.136263         0.0      0.0
# 4    108.203537      0.428255         0.0      0.0
# ..          ...           ...         ...      ...
# 488  111.069550      0.136095         0.0      0.0
# 489  112.719803      0.019123         1.0      0.0
# 490   89.622620      0.224457         0.0      0.0
# 491   92.822929      0.197350         0.0      0.0
# 492  105.546913      0.388389         1.0      0.0
#
# [493 rows x 10 columns]

# %%
plt.plot(sign_df['neutronicity'], sign_df['is_neutron'],'.', color="red", label="All data")

# %%
'''PA NEG
division by zero : 0.200000
	 division by zero : 0.300000
0.400000 	 0.705173
0.500000 	 2.227520
0.600000 	 4.004642
0.700000 	 4.038667
0.800000 	 4.046265
0.900000 	 4.044426
1.000000 	 4.008892
1.100000 	 3.622775
1.200000 	 3.359773
1.300000 	 3.120249
1.400000 	 2.999718
1.500000 	 2.904303
'''
'''
svm
0.100000 	 2.531322      0.100000 	 2.531322
0.150000 	 2.589749      0.150000 	 2.589749
0.200000 	 2.914193      0.200000 	 2.914193
0.250000 	 3.518699      0.250000 	 3.518699
0.300000 	 4.212121
0.350000 	 4.436455
0.400000 	 3.946117
0.450000 	 4.125414
0.500000 	 4.150950
0.550000 	 3.773591
0.600000 	 3.754675
0.650000 	 3.917257
0.700000 	 4.576388
0.750000 	 3.612938
0.800000 	 3.834937
0.850000 	 3.754675
	 division by zero : 0.900000
	 division by zero : 0.950000
	 division by zero : 1.000000
	 division by zero : 1.050000
'''
# Out:
# '\nsvm\n0.100000 \t 2.531322\n0.150000 \t 2.589749\n0.200000 \t 2.914193\n0.250000 \t 3.518699\n0.300000 \t 4.212121\n0.350000 \t 4.436455\n0.400000 \t 3.946117\n0.450000 \t 4.125414\n0.500000 \t 4.150950\n0.550000 \t 3.773591\n0.600000 \t 3.754675\n0.650000 \t 3.917257\n0.700000 \t 4.576388\n0.750000 \t 3.612938\n0.800000 \t 3.834937\n0.850000 \t 3.754675\n\t division by zero : 0.900000\n\t division by zero : 0.950000\n\t division by zero : 1.000000\n\t division by zero : 1.050000\n'

# %%
'''
PA POS
0.400000 	 1.835619
0.500000 	 3.059769
0.600000 	 3.408084
0.700000 	 3.645216
0.800000 	 3.614504
0.900000 	 3.346760
1.000000 	 2.701402
1.100000 	 2.332590
1.200000 	 2.106348
1.300000 	 1.980825
1.400000 	 1.920200
1.500000 	 1.888297
'''
'''
svm POS
0.100000 	 1.831857
0.150000 	 2.106061
0.200000 	 2.609680
0.250000 	 3.034294
0.300000 	 3.917997
0.350000 	 2.711710
0.400000 	 3.539942
0.450000 	 2.949951
0.500000 	 3.337489
0.550000 	 2.920303
0.600000 	 2.503117
0.650000 	 1.668745
0.700000 	 1.251558
0.750000 	 1.251558
0.800000 	 0.417186
'''
# Out:
# '\nsvm POS\n0.100000 \t 1.831857\n0.150000 \t 2.106061\n0.200000 \t 2.609680\n0.250000 \t 3.034294\n0.300000 \t 3.917997\n0.350000 \t 2.711710\n0.400000 \t 3.539942\n0.450000 \t 2.949951\n0.500000 \t 3.337489\n0.550000 \t 2.920303\n0.600000 \t 2.503117\n0.650000 \t 1.668745\n0.700000 \t 1.251558\n0.750000 \t 1.251558\n0.800000 \t 0.417186\n'
