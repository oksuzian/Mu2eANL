# %% [markdown]
# <a href="https://colab.research.google.com/github/oksuzian/Mu2eANL/blob/master/CRVML/NN/TrainCRV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Init

# %%
import sys

# This allows you to run on Colaboratory and load files from your Google Drive
try:
    from google.colab import drive
    drive.mount("/content/drive")
    main_path = '/content/drive/My Drive/'
except:
    main_path = ''
sys.path.append(main_path)
# Out:
# Mounted at /content/drive

# %%
# !pip install --upgrade tables
# Out:
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (3.4.4)
# Collecting tables
#   Downloading tables-3.6.1-cp37-cp37m-manylinux1_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 9.6 MB/s
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables) (2.7.3)
# Requirement already satisfied: numpy>=1.9.3 in /usr/local/lib/python3.7/dist-packages (from tables) (1.19.5)
# Installing collected packages: tables
#   Attempting uninstall: tables
#     Found existing installation: tables 3.4.4
#     Uninstalling tables-3.4.4:
#       Successfully uninstalled tables-3.4.4
# Successfully installed tables-3.6.1

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.1f' % x)
plt.style.use('seaborn-whitegrid')
plt.rcParams["grid.linestyle"] = (5,15)
plt.rcParams["grid.linewidth"] = 0.5
plt.rcParams["figure.figsize"] = (10,5)
plt.rcParams.update({'font.size': 22})

#Keras libs
import keras
from keras.models import Sequential, Model, Input
from keras.layers.core import Dense, Activation
from keras.layers import BatchNormalization, Dropout, concatenate
from keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from tensorflow.keras.optimizers import Adam
import keras.backend as K
from keras.models import load_model

import math
import sklearn.utils
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.model_selection import train_test_split

from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import brier_score_loss

import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, cohen_kappa_score, plot_confusion_matrix
import string
from decimal import Decimal
from mpl_toolkits.axisartist.axislines import AxesZero
import pickle

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
'''
# !pip install wandb
import wandb
wandb.init()
'''
# Out:
# '\n!pip install wandb\nimport wandb\nwandb.init()\n'

# %% [markdown]
# #Define var list and cuts

# %%
dTZPE_noMom_variables_list = {
                  'crvinfo__z': [-5000, 20000],
                  'crvinfo__y': [-5000, 5000],
                  'crvinfo__PEs': [-1, 1000],
                  'crvinfo__dT': [-500, 500],
                  'crvinfo__nCoincidenceHits': [0, 50],
#                  'de_nhits': [-2, 100],
                  # 'ue_nhits': [-2, 100],
                  'dequal_TrkPID': [-1.1, 1.1],
                  'dequal_TrkQual': [-0.1, 1.1],
                  'deent_td': [0, 10],
                  'deent_z0': [-500,500],
                  }

#Default MDC-style cut box
cuts = [
    "(de_status > 0)",
    "(deent_td > 0.577350)",
    "(deent_td < 1.000)",
    "(deent_d0 > -80)",
    "(deent_d0 < 105)",
    "((deent_d0 + 2./deent_om) > 450)",
    "((deent_d0 + 2./deent_om) < 680)",
    "(is_triggered)"
]
cut_tbox = " & ".join(cuts)
#PID, TrkQual and cut on events with an usptream leg
cuts = [
    "(dequal_TrkQual > 0.8)",
    "(dequal_TrkPID > 0.95)",
    "(ue_status <= 0)"
]
cut_pid_trkqual_ue = " & ".join(cuts)
# Extended momentum window cut`
cuts = [
    "(deent_mom > 100)",
    "(deent_mom < 115)"
]
cut_extmom = " & ".join(cuts)
cuts = [
    "(deent_mom > 103.85)",
    "(deent_mom < 105.1)"
]
cut_phymom = " & ".join(cuts)
# Loose box cuts
cuts = [
    "(deent_td > 0.577350)",
    "(deent_td < 1.000)",
    "(deent_d0 > -80)",
    "(deent_d0 < 205)",
    "((deent_d0 + 2./deent_om) > 450)",
    "(is_triggered)"
]

crv_time = "( ((-de_t0 + crvinfo__timeWindowStart) > 50) | ((de_t0-crvinfo__timeWindowStart) > 150.0)) "
cut_lbox = " & ".join(cuts)
cut_lbox = " & ".join(cuts)

# %%
#Combime cuts
cut_nomom  = cut_tbox +" & "+cut_pid_trkqual_ue
cut_extmom_orig = cut_extmom
cut_extmom =  cut_tbox +" & "+cut_pid_trkqual_ue+" & "+cut_extmom
cut_phymom = cut_tbox +" & "+cut_pid_trkqual_ue+" & "+cut_phymom
cut_loose  = cut_lbox +" & "+cut_pid_trkqual_ue

# %% [markdown]
# #Load training dataframe

# %%
# Load dataframe
df = pd.read_hdf(main_path+"Saved_Data/TrainingDataCRY3CE.h5")

#Plot basic variables
plotted = df.query('(is_high != -1) & crvinfo__timeWindowStart>0')
plt.hist2d(plotted['crvinfomc__z'], plotted['crvinfomc__x'], bins=(200,200), norm=matplotlib.colors.LogNorm(), cmap=plt.cm.jet);
plt.colorbar();
plt.title("CRY3 Cosmic Distribution");
plt.xlabel("z");
plt.ylabel("x");

plt.figure()
plotted = df.query('(is_high == -1) & crvinfo__timeWindowStart>0')
plt.hist2d(plotted['crvinfomc__z'], plotted['crvinfomc__x'], bins=(200,200), norm=matplotlib.colors.LogNorm(), cmap=plt.cm.jet);
plt.colorbar();
plt.title("CE/Noise Distribution");
plt.xlabel("z");
plt.ylabel("x");

plt.figure()
plt.hist(df['is_high'], bins=100);

# %% [markdown]
# #Create training and validation datasets

# %%
selector='('+cut_extmom+'& is_cosmic==0'+') | is_cosmic==1'
onlyCRV = df[(df['crvinfo__PEs']>=-1)] #Data Filtration
onlyCRV = onlyCRV.query(selector)
var_list=list(dTZPE_noMom_variables_list.keys())
var_list.append('is_cosmic')
onlyCRV = onlyCRV[var_list]

# %%
y_CRV = onlyCRV['is_cosmic']
X_CRV = onlyCRV.drop('is_cosmic', 1)
CRV_X_train_df, CRV_X_val_df, CRV_y_train, CRV_y_val = train_test_split(X_CRV, y_CRV, test_size=0.25, random_state=1)
CRV_y_train = np.ravel(CRV_y_train).flatten()
CRV_y_val = np.ravel(CRV_y_val).flatten()

CRVscaler = StandardScaler().fit(X_CRV)
CRV_X_train = CRVscaler.transform(CRV_X_train_df)
CRV_X_val = CRVscaler.transform(CRV_X_val_df)

# %%
'''
with open(main_path+"Saved_Data/CoincidenceTrainer.pkl", "wb+") as f:
  pickle.dump([CRV_y_train, CRV_y_val, CRVscaler, CRV_X_train, CRV_X_val, CRV_X_train_df, CRV_X_val_df], f)
with open(main_path+"Saved_Data/CoincidenceTestingCE.pkl", "wb+") as f:
  pickle.dump([CRV_y_test, CRV_X_test_df], f)
'''
# Out:
# '\nwith open(main_path+"Saved_Data/CoincidenceTrainer.pkl", "wb+") as f:\n  pickle.dump([CRV_y_train, CRV_y_val, CRVscaler, CRV_X_train, CRV_X_val, CRV_X_train_df, CRV_X_val_df], f)\nwith open(main_path+"Saved_Data/CoincidenceTestingCE.pkl", "wb+") as f:\n  pickle.dump([CRV_y_test, CRV_X_test_df], f)\n'

# %% [markdown]
# #Train model

# %%
X_train = CRV_X_train
y_train = CRV_y_train
X_val = CRV_X_val
y_val = CRV_y_val

# %%
from __future__ import absolute_import
from __future__ import print_function
import datetime

# %load_ext tensorboard
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
# !rm -rf ./logs/

keras.backend.clear_session() #This clears the previous training
model = keras.Sequential()
widthMultiplier = 2
depth = 3 
batch = 2000000

width = round(len(X_train[0])*widthMultiplier)
model.add(Dense(len(X_train[0]), input_dim=len(X_train[0]), kernel_initializer='normal', activation='relu'))
model.add(Dense(width, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

#history = model.fit(x=X_train, y=y_train, epochs=10000, batch_size=batch, validation_data=(X_val, y_val), verbose=1, callbacks=[tensorboard_callback]);
history = model.fit(x=X_train, y=y_train, epochs=50000, batch_size=batch, validation_data=(X_val, y_val), verbose=1);
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47502/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47503/50000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47504/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47505/50000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47506/50000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47507/50000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47508/50000
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47509/50000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47510/50000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47511/50000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47512/50000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47513/50000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47514/50000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47515/50000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47516/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47517/50000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47518/50000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47519/50000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47520/50000
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47521/50000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47522/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47523/50000
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47524/50000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47525/50000
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47526/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47527/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47528/50000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47529/50000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47530/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47531/50000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47532/50000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47533/50000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47534/50000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47535/50000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47536/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47537/50000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47538/50000
# 1/1 [==============================] - 0s 140ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47539/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47540/50000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47541/50000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47542/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47543/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47544/50000
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47545/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47546/50000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47547/50000
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47548/50000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47549/50000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47550/50000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47551/50000
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47552/50000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47553/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47554/50000
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47555/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47556/50000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47557/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47558/50000
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47559/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47560/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47561/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47562/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47563/50000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47564/50000
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47565/50000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47566/50000
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47567/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47568/50000
# 1/1 [==============================] - 0s 99ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47569/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47570/50000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47571/50000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47572/50000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47573/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47574/50000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47575/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47576/50000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47577/50000
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47578/50000
# 1/1 [==============================] - 0s 151ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47579/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47580/50000
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47581/50000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47582/50000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47583/50000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47584/50000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47585/50000
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47586/50000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47587/50000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47588/50000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47589/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47590/50000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47591/50000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47592/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47593/50000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47594/50000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47595/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47596/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47597/50000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47598/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47599/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47600/50000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47601/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47602/50000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47603/50000
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47604/50000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47605/50000
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47606/50000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47607/50000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47608/50000
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47609/50000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47610/50000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47611/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47612/50000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47613/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47614/50000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47615/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47616/50000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47617/50000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47618/50000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47619/50000
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47620/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47621/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47622/50000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47623/50000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47624/50000
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47625/50000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47626/50000
# 1/1 [==============================] - 0s 97ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47627/50000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47628/50000
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47629/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47630/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47631/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47632/50000
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47633/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47634/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47635/50000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47636/50000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47637/50000
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47638/50000
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47639/50000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47640/50000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47641/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47642/50000
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47643/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47644/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47645/50000
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47646/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47647/50000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47648/50000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47649/50000
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47650/50000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47651/50000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47652/50000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47653/50000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47654/50000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47655/50000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47656/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47657/50000
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47658/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47659/50000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47660/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47661/50000
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47662/50000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47663/50000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47664/50000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47665/50000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47666/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47667/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47668/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47669/50000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47670/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47671/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47672/50000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47673/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47674/50000
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47675/50000
# 1/1 [==============================] - 0s 135ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47676/50000
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47677/50000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47678/50000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47679/50000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47680/50000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47681/50000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47682/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47683/50000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47684/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47685/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47686/50000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47687/50000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47688/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47689/50000
# 1/1 [==============================] - 0s 129ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47690/50000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47691/50000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47692/50000
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47693/50000
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47694/50000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47695/50000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47696/50000
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47697/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47698/50000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47699/50000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47700/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47701/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47702/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47703/50000
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47704/50000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47705/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47706/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47707/50000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47708/50000
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47709/50000
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47710/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47711/50000
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47712/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47713/50000
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47714/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47715/50000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47716/50000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47717/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47718/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47719/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47720/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47721/50000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47722/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47723/50000
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47724/50000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47725/50000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47726/50000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47727/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47728/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47729/50000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47730/50000
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47731/50000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47732/50000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47733/50000
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47734/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47735/50000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47736/50000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47737/50000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47738/50000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47739/50000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47740/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47741/50000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47742/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47743/50000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47744/50000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47745/50000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47746/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47747/50000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47748/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47749/50000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47750/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47751/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47752/50000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47753/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47754/50000
# 1/1 [==============================] - 0s 134ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47755/50000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47756/50000
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47757/50000
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47758/50000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47759/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47760/50000
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47761/50000
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47762/50000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47763/50000
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47764/50000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47765/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47766/50000
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47767/50000
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47768/50000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47769/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47770/50000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47771/50000
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47772/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47773/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47774/50000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47775/50000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47776/50000
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47777/50000
# 1/1 [==============================] - 0s 128ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47778/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47779/50000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47780/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47781/50000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47782/50000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47783/50000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47784/50000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47785/50000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47786/50000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47787/50000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47788/50000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47789/50000
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47790/50000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47791/50000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47792/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47793/50000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47794/50000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47795/50000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47796/50000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47797/50000
# 1/1 [==============================] - 0s 130ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47798/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47799/50000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47800/50000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47801/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47802/50000
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47803/50000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47804/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47805/50000
# 1/1 [==============================] - 0s 100ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47806/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47807/50000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47808/50000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47809/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47810/50000
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47811/50000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47812/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47813/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47814/50000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47815/50000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47816/50000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47817/50000
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47818/50000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47819/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47820/50000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47821/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47822/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47823/50000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47824/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47825/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47826/50000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 47827/50000
# ...
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49893/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49894/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49895/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49896/50000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49897/50000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49898/50000
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49899/50000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49900/50000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49901/50000
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49902/50000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49903/50000
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49904/50000
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49905/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49906/50000
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49907/50000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49908/50000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49909/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49910/50000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49911/50000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49912/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49913/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49914/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49915/50000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49916/50000
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49917/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49918/50000
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49919/50000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49920/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49921/50000
# 1/1 [==============================] - 0s 136ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49922/50000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49923/50000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49924/50000
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49925/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49926/50000
# 1/1 [==============================] - 0s 102ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49927/50000
# 1/1 [==============================] - 0s 127ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49928/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49929/50000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49930/50000
# 1/1 [==============================] - 0s 144ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49931/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49932/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49933/50000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49934/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49935/50000
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49936/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49937/50000
# 1/1 [==============================] - 0s 121ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49938/50000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49939/50000
# 1/1 [==============================] - 0s 132ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49940/50000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49941/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49942/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49943/50000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49944/50000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49945/50000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49946/50000
# 1/1 [==============================] - 0s 123ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49947/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49948/50000
# 1/1 [==============================] - 0s 115ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49949/50000
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49950/50000
# 1/1 [==============================] - 0s 118ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49951/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49952/50000
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49953/50000
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49954/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49955/50000
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49956/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49957/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49958/50000
# 1/1 [==============================] - 0s 95ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49959/50000
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49960/50000
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49961/50000
# 1/1 [==============================] - 0s 140ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49962/50000
# 1/1 [==============================] - 0s 124ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49963/50000
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49964/50000
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49965/50000
# 1/1 [==============================] - 0s 135ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49966/50000
# 1/1 [==============================] - 0s 98ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49967/50000
# 1/1 [==============================] - 0s 126ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49968/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49969/50000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49970/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49971/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49972/50000
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49973/50000
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49974/50000
# 1/1 [==============================] - 0s 131ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49975/50000
# 1/1 [==============================] - 0s 112ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49976/50000
# 1/1 [==============================] - 0s 133ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49977/50000
# 1/1 [==============================] - 0s 111ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49978/50000
# 1/1 [==============================] - 0s 101ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49979/50000
# 1/1 [==============================] - 0s 105ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49980/50000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49981/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49982/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49983/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49984/50000
# 1/1 [==============================] - 0s 119ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49985/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49986/50000
# 1/1 [==============================] - 0s 108ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49987/50000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49988/50000
# 1/1 [==============================] - 0s 104ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49989/50000
# 1/1 [==============================] - 0s 117ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49990/50000
# 1/1 [==============================] - 0s 110ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49991/50000
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49992/50000
# 1/1 [==============================] - 0s 136ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49993/50000
# 1/1 [==============================] - 0s 120ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49994/50000
# 1/1 [==============================] - 0s 106ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49995/50000
# 1/1 [==============================] - 0s 113ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49996/50000
# 1/1 [==============================] - 0s 103ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49997/50000
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49998/50000
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 49999/50000
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993
# Epoch 50000/50000
# 1/1 [==============================] - 0s 88ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0022 - val_accuracy: 0.9993

# %%
#%tensorboard --logdir logs/fit

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharex=True, figsize=(14,5))

ax1.plot(history.history['accuracy'], label="training");
ax1.plot(history.history['val_accuracy'], label="validation");
ax1.set_title('model accuracy');
ax1.set_ylabel('accuracy');
ax1.set_xlabel('epoch');
ax1.legend(loc='bottom right');
#ax1.set_ylim(0.9,1);
ax1.set_yscale('log');

ax2.plot(history.history['loss'], 'r-', label="training")
ax2.plot(history.history['val_loss'], 'g-', label="validation")
ax2.set_title('model loss');
ax2.set_ylabel('loss');
ax2.set_xlabel('epoch');
ax2.legend(loc='best');
#ax2.set_ylim(0,0.1);
ax2.set_yscale('log');
plt.tight_layout();
plt.show()

# %%
try:
    variousYields
except NameError:
    variousYields = pd.read_hdf(main_path + "root_files_cry4/cry4df.h5").query(cut_loose)

plotted = variousYields.query('crvinfo__timeWindowStart>0')

plt.hist2d(plotted['crvinfomc__z'], plotted['crvinfomc__x'], bins=(200,200), norm=matplotlib.colors.LogNorm(), cmap=plt.cm.jet);
plt.colorbar();
plt.title("CRY4 Cosmic Distribution");
plt.xlabel("z");
plt.ylabel("x");

# %%
noise = df.query(cut_extmom+'& is_cosmic==0 & crvinfo__PEs>-1') 
noise_X_test = CRVscaler.transform(noise[list(dTZPE_noMom_variables_list.keys())])
withCRV = variousYields[(variousYields['crvinfo__PEs']>-1)] 
withCRV_X_test = CRVscaler.transform(withCRV[list(dTZPE_noMom_variables_list.keys())])
withCRV_X_pred = model.predict(withCRV_X_test)
withCRV['pred'] = withCRV_X_pred.flatten().tolist()

withCRV_X_pred = model.predict(noise_X_test)
noise['pred'] = withCRV_X_pred.flatten().tolist()

noiseNoCRV = df.query(cut_extmom+'& is_cosmic==0 & crvinfo__PEs<-1') 
noiseNoCRV['pred']=0
noise = pd.concat([noiseNoCRV, noise], axis=0)

# %%
for lyield in range(9000, 17001, 2000):
  print(lyield)
  plt.figure()
  plt.hist(noise['pred'], bins=np.arange(0,1.0, 0.001), histtype='step', label='noise and lyield==16545');
  plt.hist(withCRV.query(cut_extmom+'& lyield==%d'%lyield)['pred'], bins=np.arange(0,1.0, 0.001), histtype='step', label='cosmic and lyield==%d'%lyield);
  plt.yscale('log')
  plt.legend()

plt.figure()
plt.hist(noise['pred'], bins=np.arange(0,1.0, 0.001), histtype='step', label='noise and lyield==16545');
plt.hist(withCRV.query(cut_extmom+'& lyield==17000')['pred'], bins=np.arange(0,1.0, 0.001), histtype='step', label='cosmic and lyield==17000');
plt.yscale('log')
plt.xlim(0, 0.2)
plt.legend()
# Out:
# 9000
# 11000
# 13000
# 15000
# 17000

# %%
plt.hist(noise['evtinfo__nprotons'], bins=100, histtype='step');
plt.figure()
plt.hist(noise.query('evtinfo__nprotons>1E8')['pred'], bins=100, histtype='step');
plt.yscale('log')

# %%
fig.subplots_adjust(hspace=0)
fig, (ax1, ax2) = plt.subplots(nrows=2, sharex=True)
fig.subplots_adjust(0,0,1,1,0,0)

ax1.hist(noise['pred'], bins=np.arange(0,1.0, 0.001), histtype='step', cumulative=True, density=True, label='Beam intens: all');
ax1.hist(noise.query('evtinfo__nprotons>1E8')['pred'], bins=np.arange(0,1.0, 0.001), histtype='step', cumulative=True, density=True, label='Beam intens: >1E8');
ax1.set_yscale('log')
ax1.set_ylim(0.7, 1.0)
ax1.set_ylabel('CE efficiency')
ax1.legend()


ax2.hist(withCRV.query(cut_extmom+'& lyield==17000')['pred'], bins=np.arange(0,1.0, 0.001), histtype='step', cumulative=True, density=True, label='cosmic and lyield==17000');
plt.yscale('log')
#plt.xlim(0.05,0.3)
ax2.set_ylabel('Background efficiency')
# Out:
# Text(0, 0.5, 'Background efficiency')

# %%
withCRV['is_cosmic'] = 1
x_combo = withCRV['pred'].append(noise['pred']).to_numpy()
y_combo = withCRV['is_cosmic'].append(noise['is_cosmic']).to_numpy()
fpr, tpr, _ = roc_curve(y_combo, x_combo)

plt.plot(fpr, tpr, linestyle='--', label='without PE')
plt.yscale('log')
plt.ylim(0.9999, 1)
plt.legend()

# %%
nncut=0.1

plotted_all = variousYields.query(cut_extmom+'& crvinfo__timeWindowStart>0 & lyield==17000')
plotted = withCRV.query(cut_extmom+'& crvinfo__timeWindowStart>0 & lyield==17000 & pred<%f'%nncut)

plt.hist2d(plotted_all['crvinfomc__z'], plotted_all['crvinfomc__x'], bins=(200,200), norm=matplotlib.colors.LogNorm(), cmap=plt.cm.jet);
plt.colorbar();
plt.title("CRY4 Cosmic Distribution");
plt.xlabel("z [mm]");
plt.ylabel("x [mm]");

plt.plot(plotted['crvinfomc__z'], plotted['crvinfomc__x'], 'ro', label='non-vetoed');
plt.legend()

plt.figure()
plt.hist(plotted['crvinfo__PEs'], bins=range(0,1000,1), histtype='step', label='non-vetoed');
plt.hist(plotted_all['crvinfo__PEs'], bins=range(0,1000,1), histtype='step', label='All');
plt.xlabel('PE')
plt.yscale('log')
plt.legend()

plt.figure()
plt.hist(plotted['crvinfo__dT'], bins=range(-200,200,1), histtype='step', label='non-vetoed');
plt.hist(plotted_all['crvinfo__dT'], bins=range(-200,200,1), histtype='step', label='All');
plt.xlabel('dT [ns]')
plt.yscale('log')
plt.legend()

# %% [markdown]
# #Save CRY4 data

# %%
withNoCRV = variousYields[(variousYields['crvinfo__PEs']<-1)] 
withNoCRV['pred'] = 0
withCRV['is_cosmic'] = 1
pd.concat([withNoCRV, withCRV], axis=0).to_hdf(main_path+"root_files_cry4/cr4dfml.hd5", key='df', mode='w')
noise.to_hdf(main_path+"root_files_cry4/noisedfml.hd5", key='noise', mode='w')
