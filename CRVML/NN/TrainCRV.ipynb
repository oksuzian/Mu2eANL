# %% [markdown]
# <a href="https://colab.research.google.com/github/oksuzian/Mu2eANL/blob/master/CRVML/NN/TrainCRV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Init

# %%
import sys

# This allows you to run on Colaboratory and load files from your Google Drive
try:
    from google.colab import drive
    drive.mount("/content/drive")
    main_path = '/content/drive/My Drive/'
except:
    main_path = ''
sys.path.append(main_path)
# Out:
# Mounted at /content/drive

# %%
# !pip install --upgrade tables
# !pip install uproot3
# Out:
# Requirement already satisfied: tables in /usr/local/lib/python3.7/dist-packages (3.4.4)
# Collecting tables
#   Downloading tables-3.6.1-cp37-cp37m-manylinux1_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 5.4 MB/s
# Requirement already satisfied: numpy>=1.9.3 in /usr/local/lib/python3.7/dist-packages (from tables) (1.19.5)
# Requirement already satisfied: numexpr>=2.6.2 in /usr/local/lib/python3.7/dist-packages (from tables) (2.7.3)
# Installing collected packages: tables
#   Attempting uninstall: tables
#     Found existing installation: tables 3.4.4
#     Uninstalling tables-3.4.4:
#       Successfully uninstalled tables-3.4.4
# Successfully installed tables-3.6.1
# Collecting uproot3
#   Downloading uproot3-3.14.4-py3-none-any.whl (117 kB)
#      |████████████████████████████████| 117 kB 5.3 MB/s
# Requirement already satisfied: numpy>=1.13.1 in /usr/local/lib/python3.7/dist-packages (from uproot3) (1.19.5)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.7/dist-packages (from uproot3) (4.2.4)
# Collecting uproot3-methods
#   Downloading uproot3_methods-0.10.1-py3-none-any.whl (32 kB)
# Collecting awkward0
#   Downloading awkward0-0.15.5-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 5.7 MB/s
# Installing collected packages: awkward0, uproot3-methods, uproot3
# Successfully installed awkward0-0.15.5 uproot3-3.14.4 uproot3-methods-0.10.1

# %%
import uproot3
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from plotly import graph_objs as go
import pylab
import seaborn as sns
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.1f' % x)
plt.style.use('seaborn-whitegrid')
plt.rcParams["grid.linestyle"] = (5,15)
plt.rcParams["grid.linewidth"] = 0.5
plt.rcParams["figure.figsize"] = (10,5)
plt.rcParams.update({'font.size': 22})

#Keras libs
import keras
from keras.models import Sequential, Model, Input
from keras.layers.core import Dense, Activation
from keras.layers import BatchNormalization, Dropout, concatenate
from keras.callbacks import ModelCheckpoint, EarlyStopping, Callback
from tensorflow.keras.optimizers import Adam
import keras.backend as K
from keras.models import load_model

import math
import sklearn.utils
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.model_selection import train_test_split

from sklearn.metrics import roc_curve
from sklearn.metrics import auc
from sklearn.metrics import brier_score_loss
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, cohen_kappa_score, plot_confusion_matrix
import string
from decimal import Decimal
from mpl_toolkits.axisartist.axislines import AxesZero
import pickle

# %% [markdown]
# #Define var list and cuts

# %%
dTZPE_noMom_variables_list = {
                  'crvinfo__z': [-5000, 20000],
                  'crvinfo__PEs': [-1, 1000],
                  'crvinfo__dT': [-500, 500],
                  'crvinfo__nCoincidenceHits': [0, 50],
#                  'de_nhits': [-2, 100],
                  # 'ue_nhits': [-2, 100],
                  'dequal_TrkPID': [-1.1, 1.1],
#                  'dequal_TrkQual': [-0.1, 1.1],
#                  'deent_td': [0, 10],
#                  'deent_z0': [-500,500],
                  }

#Default MDC-style cut box
cuts = [
    "(de_status > 0)",
    "(deent_td > 0.577350)",
    "(deent_td < 1.000)",
    "(deent_d0 > -80)",
    "(deent_d0 < 105)",
    "((deent_d0 + 2./deent_om) > 450)",
    "((deent_d0 + 2./deent_om) < 680)",
    "(is_triggered)"
]
cut_tbox = " & ".join(cuts)
#PID, TrkQual and cut on events with an usptream leg
cuts = [
    "(dequal_TrkQual > 0.8)",
    "(dequal_TrkPID > 0.95)",
    "(ue_status <= 0)"
]
cut_pid_trkqual_ue = " & ".join(cuts)
# Extended momentum window cut`
cuts = [
    "(deent_mom > 100)",
    "(deent_mom < 115)"
]
cut_extmom = " & ".join(cuts)
cuts = [
    "(deent_mom > 103.85)",
    "(deent_mom < 105.1)"
]
cut_phymom = " & ".join(cuts)
# Loose box cuts
cuts = [
    "(deent_td > 0.577350)",
    "(deent_td < 1.000)",
    "(deent_d0 > -80)",
    "(deent_d0 < 205)",
    "((deent_d0 + 2./deent_om) > 450)",
    "(is_triggered)"
]

crv_time = "( ((-de_t0 + crvinfo__timeWindowStart) > 50) | ((de_t0-crvinfo__timeWindowStart) > 150.0)) "
cut_lbox = " & ".join(cuts)
cut_lbox = " & ".join(cuts)

# %%
#Combime cuts
cut_nomom  = cut_tbox +" & "+cut_pid_trkqual_ue
cut_extmom_orig = cut_extmom
cut_extmom =  cut_tbox +" & "+cut_pid_trkqual_ue+" & "+cut_extmom
cut_phymom = cut_tbox +" & "+cut_pid_trkqual_ue+" & "+cut_phymom
cut_loose  = cut_lbox +" & "+cut_pid_trkqual_ue

# %% [markdown]
# #Load training dataframe

# %%
# Load dataframe
df = pd.read_hdf(main_path+"Saved_Data/TrainingDataCRY3CE.h5")

#Plot basic variables
plotted = df.query('(is_high != -1) & crvinfo__timeWindowStart>0')
plt.hist2d(plotted['crvinfomc__z'], plotted['crvinfomc__x'], bins=(200,200), norm=matplotlib.colors.LogNorm(), cmap=plt.cm.jet);
plt.colorbar();
plt.title("CRY3 Cosmic Distribution");
plt.xlabel("z");
plt.ylabel("x");

plt.figure()
plotted = df.query('(is_high == -1) & crvinfo__timeWindowStart>0')
plt.hist2d(plotted['crvinfomc__z'], plotted['crvinfomc__x'], bins=(200,200), norm=matplotlib.colors.LogNorm(), cmap=plt.cm.jet);
plt.colorbar();
plt.title("CE/Noise Distribution");
plt.xlabel("z");
plt.ylabel("x");

plt.figure()
plt.hist(df['is_high'], bins=100);

# %% [markdown]
# #Create training and validation datasets

# %%
selector='('+cut_extmom+'& is_cosmic==0'+') | is_cosmic==1'
onlyCRV = df[(df['crvinfo__PEs']>=-1)] #Data Filtration
onlyCRV = onlyCRV.query(selector)
var_list=list(dTZPE_noMom_variables_list.keys())
var_list.append('is_cosmic')
onlyCRV = onlyCRV[var_list]

# %%
y_CRV = onlyCRV['is_cosmic']
X_CRV = onlyCRV.drop('is_cosmic', 1)
CRV_X_train_df, CRV_X_val_df, CRV_y_train, CRV_y_val = train_test_split(X_CRV, y_CRV, test_size=0.25, random_state=1)
CRV_y_train = np.ravel(CRV_y_train).flatten()
CRV_y_val = np.ravel(CRV_y_val).flatten()

CRVscaler = StandardScaler().fit(X_CRV)
CRV_X_train = CRVscaler.transform(CRV_X_train_df)
CRV_X_val = CRVscaler.transform(CRV_X_val_df)

# %%
'''
with open(main_path+"Saved_Data/CoincidenceTrainer.pkl", "wb+") as f:
  pickle.dump([CRV_y_train, CRV_y_val, CRVscaler, CRV_X_train, CRV_X_val, CRV_X_train_df, CRV_X_val_df], f)
with open(main_path+"Saved_Data/CoincidenceTestingCE.pkl", "wb+") as f:
  pickle.dump([CRV_y_test, CRV_X_test_df], f)
'''
# Out:
# '\nwith open(main_path+"Saved_Data/CoincidenceTrainer.pkl", "wb+") as f:\n  pickle.dump([CRV_y_train, CRV_y_val, CRVscaler, CRV_X_train, CRV_X_val, CRV_X_train_df, CRV_X_val_df], f)\nwith open(main_path+"Saved_Data/CoincidenceTestingCE.pkl", "wb+") as f:\n  pickle.dump([CRV_y_test, CRV_X_test_df], f)\n'

# %% [markdown]
# #Train model

# %%
X_train = CRV_X_train
y_train = CRV_y_train
X_val = CRV_X_val
y_val = CRV_y_val

# %%
keras.backend.clear_session() #This clears the previous training
model = keras.Sequential()
widthMultiplier = 2
depth = 2 
batch = 1000

width = round(len(X_train[0])*widthMultiplier)
model.add(Dense(len(X_train[0]), input_dim=len(X_train[0]), kernel_initializer='normal', activation='relu'))
model.add(Dense(width, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(x=X_train, y=y_train, epochs=200, batch_size=batch, validation_data=(X_val, y_val), verbose=True);
# Out:
# Epoch 1/200
# 1674/1674 [==============================] - 6s 3ms/step - loss: 0.1256 - accuracy: 0.9586 - val_loss: 0.0445 - val_accuracy: 0.9847
# Epoch 2/200
# 1674/1674 [==============================] - 4s 3ms/step - loss: 0.0337 - accuracy: 0.9881 - val_loss: 0.0268 - val_accuracy: 0.9908
# Epoch 3/200
# 1674/1674 [==============================] - 5s 3ms/step - loss: 0.0249 - accuracy: 0.9911 - val_loss: 0.0239 - val_accuracy: 0.9913
# Epoch 4/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0225 - accuracy: 0.9919 - val_loss: 0.0216 - val_accuracy: 0.9923
# Epoch 5/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0212 - accuracy: 0.9924 - val_loss: 0.0206 - val_accuracy: 0.9926
# Epoch 6/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0204 - accuracy: 0.9927 - val_loss: 0.0199 - val_accuracy: 0.9928
# Epoch 7/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0199 - accuracy: 0.9929 - val_loss: 0.0196 - val_accuracy: 0.9929
# Epoch 8/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0196 - accuracy: 0.9930 - val_loss: 0.0191 - val_accuracy: 0.9932
# Epoch 9/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0193 - accuracy: 0.9930 - val_loss: 0.0188 - val_accuracy: 0.9932
# Epoch 10/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0191 - accuracy: 0.9931 - val_loss: 0.0186 - val_accuracy: 0.9933
# Epoch 11/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0189 - accuracy: 0.9932 - val_loss: 0.0184 - val_accuracy: 0.9934
# Epoch 12/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0187 - accuracy: 0.9933 - val_loss: 0.0183 - val_accuracy: 0.9934
# Epoch 13/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0186 - accuracy: 0.9934 - val_loss: 0.0185 - val_accuracy: 0.9933
# Epoch 14/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0185 - accuracy: 0.9934 - val_loss: 0.0183 - val_accuracy: 0.9934
# Epoch 15/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0184 - accuracy: 0.9935 - val_loss: 0.0180 - val_accuracy: 0.9937
# Epoch 16/200
# 1674/1674 [==============================] - 3s 2ms/step - loss: 0.0183 - accuracy: 0.9935 - val_loss: 0.0180 - val_accuracy: 0.9935
# Epoch 17/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0182 - accuracy: 0.9935 - val_loss: 0.0180 - val_accuracy: 0.9935
# Epoch 18/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0181 - accuracy: 0.9936 - val_loss: 0.0177 - val_accuracy: 0.9937
# Epoch 19/200
# 1674/1674 [==============================] - 3s 2ms/step - loss: 0.0181 - accuracy: 0.9936 - val_loss: 0.0177 - val_accuracy: 0.9938
# Epoch 20/200
# 1674/1674 [==============================] - 3s 2ms/step - loss: 0.0180 - accuracy: 0.9937 - val_loss: 0.0176 - val_accuracy: 0.9937
# Epoch 21/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0179 - accuracy: 0.9937 - val_loss: 0.0176 - val_accuracy: 0.9937
# Epoch 22/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0178 - accuracy: 0.9937 - val_loss: 0.0174 - val_accuracy: 0.9938
# Epoch 23/200
# 1674/1674 [==============================] - 3s 2ms/step - loss: 0.0178 - accuracy: 0.9937 - val_loss: 0.0174 - val_accuracy: 0.9938
# Epoch 24/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0177 - accuracy: 0.9937 - val_loss: 0.0175 - val_accuracy: 0.9938
# Epoch 25/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0176 - accuracy: 0.9938 - val_loss: 0.0174 - val_accuracy: 0.9937
# Epoch 26/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0176 - accuracy: 0.9938 - val_loss: 0.0172 - val_accuracy: 0.9939
# Epoch 27/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0175 - accuracy: 0.9938 - val_loss: 0.0171 - val_accuracy: 0.9939
# Epoch 28/200
# 1674/1674 [==============================] - 3s 2ms/step - loss: 0.0175 - accuracy: 0.9938 - val_loss: 0.0174 - val_accuracy: 0.9938
# Epoch 29/200
# 1674/1674 [==============================] - 3s 2ms/step - loss: 0.0175 - accuracy: 0.9938 - val_loss: 0.0172 - val_accuracy: 0.9939
# Epoch 30/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0173 - accuracy: 0.9939 - val_loss: 0.0172 - val_accuracy: 0.9938
# Epoch 31/200
# 1674/1674 [==============================] - 3s 2ms/step - loss: 0.0173 - accuracy: 0.9939 - val_loss: 0.0170 - val_accuracy: 0.9940
# Epoch 32/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0173 - accuracy: 0.9939 - val_loss: 0.0170 - val_accuracy: 0.9941
# Epoch 33/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0173 - accuracy: 0.9939 - val_loss: 0.0169 - val_accuracy: 0.9940
# Epoch 34/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0172 - accuracy: 0.9939 - val_loss: 0.0169 - val_accuracy: 0.9941
# Epoch 35/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0172 - accuracy: 0.9939 - val_loss: 0.0169 - val_accuracy: 0.9940
# Epoch 36/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0171 - accuracy: 0.9939 - val_loss: 0.0168 - val_accuracy: 0.9941
# Epoch 37/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0171 - accuracy: 0.9940 - val_loss: 0.0168 - val_accuracy: 0.9941
# Epoch 38/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0171 - accuracy: 0.9940 - val_loss: 0.0166 - val_accuracy: 0.9942
# Epoch 39/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0171 - accuracy: 0.9940 - val_loss: 0.0168 - val_accuracy: 0.9941
# Epoch 40/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0170 - accuracy: 0.9940 - val_loss: 0.0166 - val_accuracy: 0.9941
# Epoch 41/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0170 - accuracy: 0.9940 - val_loss: 0.0167 - val_accuracy: 0.9941
# Epoch 42/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0170 - accuracy: 0.9940 - val_loss: 0.0168 - val_accuracy: 0.9941
# Epoch 43/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0170 - accuracy: 0.9940 - val_loss: 0.0167 - val_accuracy: 0.9942
# Epoch 44/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0170 - accuracy: 0.9940 - val_loss: 0.0172 - val_accuracy: 0.9938
# Epoch 45/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.0169 - val_accuracy: 0.9939
# Epoch 46/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.0165 - val_accuracy: 0.9941
# Epoch 47/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.0170 - val_accuracy: 0.9938
# Epoch 48/200
# 1674/1674 [==============================] - 3s 2ms/step - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.0163 - val_accuracy: 0.9942
# Epoch 49/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.0166 - val_accuracy: 0.9941
# Epoch 50/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.0164 - val_accuracy: 0.9942
# Epoch 51/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0168 - accuracy: 0.9940 - val_loss: 0.0165 - val_accuracy: 0.9942
# Epoch 52/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0168 - accuracy: 0.9940 - val_loss: 0.0164 - val_accuracy: 0.9942
# Epoch 53/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0168 - accuracy: 0.9940 - val_loss: 0.0163 - val_accuracy: 0.9942
# Epoch 54/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0168 - accuracy: 0.9941 - val_loss: 0.0164 - val_accuracy: 0.9942
# Epoch 55/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0167 - accuracy: 0.9941 - val_loss: 0.0163 - val_accuracy: 0.9942
# Epoch 56/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0167 - accuracy: 0.9941 - val_loss: 0.0164 - val_accuracy: 0.9941
# Epoch 57/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0167 - accuracy: 0.9941 - val_loss: 0.0164 - val_accuracy: 0.9941
# Epoch 58/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0167 - accuracy: 0.9940 - val_loss: 0.0164 - val_accuracy: 0.9941
# Epoch 59/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0167 - accuracy: 0.9941 - val_loss: 0.0164 - val_accuracy: 0.9942
# Epoch 60/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0167 - accuracy: 0.9941 - val_loss: 0.0163 - val_accuracy: 0.9941
# Epoch 61/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0166 - accuracy: 0.9941 - val_loss: 0.0162 - val_accuracy: 0.9942
# Epoch 62/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0166 - accuracy: 0.9941 - val_loss: 0.0164 - val_accuracy: 0.9941
# Epoch 63/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0166 - accuracy: 0.9942 - val_loss: 0.0161 - val_accuracy: 0.9944
# Epoch 64/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0165 - accuracy: 0.9941 - val_loss: 0.0160 - val_accuracy: 0.9943
# Epoch 65/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0165 - accuracy: 0.9942 - val_loss: 0.0160 - val_accuracy: 0.9943
# Epoch 66/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0165 - accuracy: 0.9942 - val_loss: 0.0162 - val_accuracy: 0.9941
# Epoch 67/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0164 - accuracy: 0.9942 - val_loss: 0.0160 - val_accuracy: 0.9943
# Epoch 68/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0164 - accuracy: 0.9942 - val_loss: 0.0159 - val_accuracy: 0.9944
# Epoch 69/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0164 - accuracy: 0.9943 - val_loss: 0.0158 - val_accuracy: 0.9945
# Epoch 70/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0164 - accuracy: 0.9943 - val_loss: 0.0163 - val_accuracy: 0.9942
# Epoch 71/200
# 1674/1674 [==============================] - 3s 2ms/step - loss: 0.0163 - accuracy: 0.9942 - val_loss: 0.0158 - val_accuracy: 0.9943
# Epoch 72/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0163 - accuracy: 0.9943 - val_loss: 0.0161 - val_accuracy: 0.9942
# Epoch 73/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0163 - accuracy: 0.9943 - val_loss: 0.0159 - val_accuracy: 0.9943
# Epoch 74/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0162 - accuracy: 0.9943 - val_loss: 0.0158 - val_accuracy: 0.9944
# Epoch 75/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0162 - accuracy: 0.9943 - val_loss: 0.0158 - val_accuracy: 0.9944
# Epoch 76/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0161 - accuracy: 0.9943 - val_loss: 0.0158 - val_accuracy: 0.9944
# Epoch 77/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0162 - accuracy: 0.9943 - val_loss: 0.0158 - val_accuracy: 0.9943
# Epoch 78/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0161 - accuracy: 0.9944 - val_loss: 0.0157 - val_accuracy: 0.9944
# Epoch 79/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0161 - accuracy: 0.9944 - val_loss: 0.0157 - val_accuracy: 0.9944
# Epoch 80/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0161 - accuracy: 0.9944 - val_loss: 0.0155 - val_accuracy: 0.9944
# Epoch 81/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0160 - accuracy: 0.9944 - val_loss: 0.0155 - val_accuracy: 0.9945
# Epoch 82/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0160 - accuracy: 0.9944 - val_loss: 0.0157 - val_accuracy: 0.9944
# Epoch 83/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0160 - accuracy: 0.9944 - val_loss: 0.0159 - val_accuracy: 0.9944
# Epoch 84/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0160 - accuracy: 0.9944 - val_loss: 0.0154 - val_accuracy: 0.9945
# Epoch 85/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0160 - accuracy: 0.9944 - val_loss: 0.0157 - val_accuracy: 0.9944
# Epoch 86/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0159 - accuracy: 0.9944 - val_loss: 0.0155 - val_accuracy: 0.9945
# Epoch 87/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0159 - accuracy: 0.9944 - val_loss: 0.0155 - val_accuracy: 0.9944
# Epoch 88/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0159 - accuracy: 0.9944 - val_loss: 0.0154 - val_accuracy: 0.9945
# Epoch 89/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0159 - accuracy: 0.9944 - val_loss: 0.0153 - val_accuracy: 0.9946
# Epoch 90/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0159 - accuracy: 0.9944 - val_loss: 0.0154 - val_accuracy: 0.9946
# Epoch 91/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0159 - accuracy: 0.9944 - val_loss: 0.0153 - val_accuracy: 0.9947
# Epoch 92/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0159 - accuracy: 0.9944 - val_loss: 0.0155 - val_accuracy: 0.9946
# Epoch 93/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0158 - accuracy: 0.9944 - val_loss: 0.0152 - val_accuracy: 0.9946
# Epoch 94/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0158 - accuracy: 0.9945 - val_loss: 0.0153 - val_accuracy: 0.9945
# Epoch 95/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0158 - accuracy: 0.9944 - val_loss: 0.0159 - val_accuracy: 0.9943
# Epoch 96/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0158 - accuracy: 0.9944 - val_loss: 0.0151 - val_accuracy: 0.9947
# Epoch 97/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0158 - accuracy: 0.9945 - val_loss: 0.0153 - val_accuracy: 0.9946
# Epoch 98/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0157 - accuracy: 0.9945 - val_loss: 0.0166 - val_accuracy: 0.9938
# Epoch 99/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0157 - accuracy: 0.9945 - val_loss: 0.0151 - val_accuracy: 0.9947
# Epoch 100/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0157 - accuracy: 0.9945 - val_loss: 0.0155 - val_accuracy: 0.9944
# Epoch 101/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0157 - accuracy: 0.9945 - val_loss: 0.0151 - val_accuracy: 0.9947
# Epoch 102/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0157 - accuracy: 0.9945 - val_loss: 0.0152 - val_accuracy: 0.9946
# Epoch 103/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.0151 - val_accuracy: 0.9947
# Epoch 104/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0157 - accuracy: 0.9945 - val_loss: 0.0151 - val_accuracy: 0.9947
# Epoch 105/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0157 - accuracy: 0.9945 - val_loss: 0.0154 - val_accuracy: 0.9944
# Epoch 106/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.0150 - val_accuracy: 0.9947
# Epoch 107/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.0152 - val_accuracy: 0.9946
# Epoch 108/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.0151 - val_accuracy: 0.9946
# Epoch 109/200
# 1674/1674 [==============================] - 5s 3ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.0151 - val_accuracy: 0.9947
# Epoch 110/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.0152 - val_accuracy: 0.9946
# Epoch 111/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.0155 - val_accuracy: 0.9944
# Epoch 112/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.0149 - val_accuracy: 0.9947
# Epoch 113/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.0152 - val_accuracy: 0.9946
# Epoch 114/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0155 - accuracy: 0.9945 - val_loss: 0.0150 - val_accuracy: 0.9946
# Epoch 115/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.0150 - val_accuracy: 0.9947
# Epoch 116/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0155 - accuracy: 0.9945 - val_loss: 0.0150 - val_accuracy: 0.9947
# Epoch 117/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0155 - accuracy: 0.9946 - val_loss: 0.0151 - val_accuracy: 0.9946
# Epoch 118/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0155 - accuracy: 0.9945 - val_loss: 0.0151 - val_accuracy: 0.9946
# Epoch 119/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0155 - accuracy: 0.9945 - val_loss: 0.0151 - val_accuracy: 0.9946
# Epoch 120/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0155 - accuracy: 0.9945 - val_loss: 0.0155 - val_accuracy: 0.9944
# Epoch 121/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0155 - accuracy: 0.9945 - val_loss: 0.0154 - val_accuracy: 0.9945
# Epoch 122/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0155 - accuracy: 0.9945 - val_loss: 0.0150 - val_accuracy: 0.9947
# Epoch 123/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 0.0150 - val_accuracy: 0.9946
# Epoch 124/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0155 - accuracy: 0.9946 - val_loss: 0.0150 - val_accuracy: 0.9946
# Epoch 125/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0155 - accuracy: 0.9945 - val_loss: 0.0154 - val_accuracy: 0.9944
# Epoch 126/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9945 - val_loss: 0.0149 - val_accuracy: 0.9948
# Epoch 127/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 0.0150 - val_accuracy: 0.9947
# Epoch 128/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 0.0149 - val_accuracy: 0.9947
# Epoch 129/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 0.0148 - val_accuracy: 0.9948
# Epoch 130/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 0.0151 - val_accuracy: 0.9946
# Epoch 131/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 0.0152 - val_accuracy: 0.9946
# Epoch 132/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9945 - val_loss: 0.0148 - val_accuracy: 0.9948
# Epoch 133/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0155 - accuracy: 0.9946 - val_loss: 0.0156 - val_accuracy: 0.9943
# Epoch 134/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 0.0156 - val_accuracy: 0.9944
# Epoch 135/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 0.0149 - val_accuracy: 0.9947
# Epoch 136/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 0.0151 - val_accuracy: 0.9946
# Epoch 137/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 0.0148 - val_accuracy: 0.9948
# Epoch 138/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0149 - val_accuracy: 0.9948
# Epoch 139/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 0.0156 - val_accuracy: 0.9943
# Epoch 140/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 0.0148 - val_accuracy: 0.9948
# Epoch 141/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0148 - val_accuracy: 0.9947
# Epoch 142/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 0.0153 - val_accuracy: 0.9945
# Epoch 143/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0154 - accuracy: 0.9946 - val_loss: 0.0149 - val_accuracy: 0.9947
# Epoch 144/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0149 - val_accuracy: 0.9947
# Epoch 145/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0149 - val_accuracy: 0.9947
# Epoch 146/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0150 - val_accuracy: 0.9946
# Epoch 147/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0149 - val_accuracy: 0.9946
# Epoch 148/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0152 - val_accuracy: 0.9945
# Epoch 149/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0149 - val_accuracy: 0.9947
# Epoch 150/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0148 - val_accuracy: 0.9948
# Epoch 151/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0152 - val_accuracy: 0.9946
# Epoch 152/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0148 - val_accuracy: 0.9948
# Epoch 153/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0147 - val_accuracy: 0.9948
# Epoch 154/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0148 - val_accuracy: 0.9947
# Epoch 155/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0147 - val_accuracy: 0.9948
# Epoch 156/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0147 - val_accuracy: 0.9948
# Epoch 157/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0152 - val_accuracy: 0.9945
# Epoch 158/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0149 - val_accuracy: 0.9947
# Epoch 159/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0149 - val_accuracy: 0.9947
# Epoch 160/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9947 - val_loss: 0.0148 - val_accuracy: 0.9948
# Epoch 161/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0147 - val_accuracy: 0.9948
# Epoch 162/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0148 - val_accuracy: 0.9948
# Epoch 163/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0148 - val_accuracy: 0.9947
# Epoch 164/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0147 - val_accuracy: 0.9948
# Epoch 165/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0148 - val_accuracy: 0.9948
# Epoch 166/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0150 - val_accuracy: 0.9945
# Epoch 167/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9947 - val_loss: 0.0147 - val_accuracy: 0.9948
# Epoch 168/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0153 - accuracy: 0.9946 - val_loss: 0.0152 - val_accuracy: 0.9945
# Epoch 169/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0148 - val_accuracy: 0.9947
# Epoch 170/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.0147 - val_accuracy: 0.9948
# Epoch 171/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9947 - val_loss: 0.0148 - val_accuracy: 0.9948
# Epoch 172/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0147 - val_accuracy: 0.9948
# Epoch 173/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0146 - val_accuracy: 0.9948
# Epoch 174/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0149 - val_accuracy: 0.9946
# Epoch 175/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9947 - val_loss: 0.0154 - val_accuracy: 0.9945
# Epoch 176/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0147 - val_accuracy: 0.9948
# Epoch 177/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9947 - val_loss: 0.0148 - val_accuracy: 0.9947
# Epoch 178/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0149 - val_accuracy: 0.9946
# Epoch 179/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0147 - val_accuracy: 0.9948
# Epoch 180/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0148 - val_accuracy: 0.9947
# Epoch 181/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0146 - val_accuracy: 0.9948
# Epoch 182/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.0146 - val_accuracy: 0.9949
# Epoch 183/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0151 - accuracy: 0.9946 - val_loss: 0.0149 - val_accuracy: 0.9946
# Epoch 184/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0145 - val_accuracy: 0.9948
# Epoch 185/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0151 - accuracy: 0.9946 - val_loss: 0.0147 - val_accuracy: 0.9948
# Epoch 186/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0151 - accuracy: 0.9946 - val_loss: 0.0148 - val_accuracy: 0.9947
# Epoch 187/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.0150 - val_accuracy: 0.9946
# Epoch 188/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0149 - val_accuracy: 0.9946
# Epoch 189/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.0145 - val_accuracy: 0.9949
# Epoch 190/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0151 - accuracy: 0.9946 - val_loss: 0.0149 - val_accuracy: 0.9947
# Epoch 191/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0147 - val_accuracy: 0.9947
# Epoch 192/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.0145 - val_accuracy: 0.9949
# Epoch 193/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0151 - accuracy: 0.9946 - val_loss: 0.0147 - val_accuracy: 0.9947
# Epoch 194/200
# 1674/1674 [==============================] - 4s 3ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.0149 - val_accuracy: 0.9946
# Epoch 195/200
# 1674/1674 [==============================] - 4s 3ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.0152 - val_accuracy: 0.9945
# Epoch 196/200
# 1674/1674 [==============================] - 4s 3ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.0148 - val_accuracy: 0.9946
# Epoch 197/200
# 1674/1674 [==============================] - 4s 3ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.0146 - val_accuracy: 0.9948
# Epoch 198/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.0145 - val_accuracy: 0.9948
# Epoch 199/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.0145 - val_accuracy: 0.9949
# Epoch 200/200
# 1674/1674 [==============================] - 4s 2ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.0148 - val_accuracy: 0.9947

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, sharex=True, figsize=(14,5))

ax1.plot(history.history['accuracy'], label="training");
ax1.plot(history.history['val_accuracy'], label="validation");
ax1.set_title('model accuracy');
ax1.set_ylabel('accuracy');
ax1.set_xlabel('epoch');
ax1.legend(loc='bottom right');
#ax1.set_ylim(0.9,1);
ax1.set_yscale('log');

ax2.plot(history.history['loss'], 'r-', label="training")
ax2.plot(history.history['val_loss'], 'g-', label="validation")
ax2.set_title('model loss');
ax2.set_ylabel('loss');
ax2.set_xlabel('epoch');
ax2.legend(loc='best');
#ax2.set_ylim(0,0.1);
ax2.set_yscale('log');
plt.tight_layout();
plt.show()

# %%
try:
    variousYields
except NameError:
    variousYields = pd.read_hdf(main_path + "root_files_cry4/cry4df.h5").query(cut_loose)

plotted = variousYields.query('crvinfo__timeWindowStart>0')

plt.hist2d(plotted['crvinfomc__z'], plotted['crvinfomc__x'], bins=(200,200), norm=matplotlib.colors.LogNorm(), cmap=plt.cm.jet);
plt.colorbar();
plt.title("CRY4 Cosmic Distribution");
plt.xlabel("z");
plt.ylabel("x");

# %%
noise = df.query(cut_extmom+'& is_cosmic==0 & crvinfo__PEs>-1') 
noise_X_test = CRVscaler.transform(noise[list(dTZPE_noMom_variables_list.keys())])
withCRV = variousYields[(variousYields['crvinfo__PEs']>-1)] 
withCRV_X_test = CRVscaler.transform(withCRV[list(dTZPE_noMom_variables_list.keys())])
withCRV_X_pred = model.predict(withCRV_X_test)
withCRV['pred'] = withCRV_X_pred.flatten().tolist()

withCRV_X_pred = model.predict(noise_X_test)
noise['pred'] = withCRV_X_pred.flatten().tolist()

# %%
for lyield in range(9000, 17001, 2000):
  print(lyield)
  plt.figure()
  plt.hist(noise['pred'], bins=np.arange(0,1.0, 0.001), histtype='step', label='noise and lyield==16545');
  plt.hist(withCRV.query(cut_extmom+'& lyield==%d'%lyield)['pred'], bins=np.arange(0,1.0, 0.001), histtype='step', label='cosmic and lyield==%d'%lyield);
  plt.yscale('log')
  plt.legend()

plt.figure()
plt.hist(noise['pred'], bins=np.arange(0,1.0, 0.001), histtype='step', label='noise and lyield==16545');
plt.hist(withCRV.query(cut_extmom+'& lyield==17000')['pred'], bins=np.arange(0,1.0, 0.001), histtype='step', label='cosmic and lyield==17000');
plt.yscale('log')
plt.xlim(0, 0.2)
plt.legend()
# Out:
# 9000
# 11000
# 13000
# 15000
# 17000

# %%
fig.subplots_adjust(hspace=0)
fig, (ax1, ax2) = plt.subplots(nrows=2, sharex=True)
fig.subplots_adjust(0,0,1,1,0,0)

ax1.hist(noise['pred'], bins=np.arange(0,1.0, 0.001), histtype='step', cumulative=True, density=True, label='noise and lyield==16545');
ax1.set_yscale('log')
ax1.set_ylabel('CE efficiency')

ax2.hist(withCRV.query(cut_extmom+'& lyield==17000')['pred'], bins=np.arange(0,1.0, 0.001), histtype='step', cumulative=True, density=True, label='cosmic and lyield==17000');
plt.yscale('log')
plt.xlim(0,0.3)
ax2.set_ylabel('Background efficiency')
# Out:
# Text(0, 0.5, 'Background efficiency')

# %%
withCRV['is_cosmic'] = 1
x_combo = withCRV['pred'].append(noise['pred']).to_numpy()
y_combo = withCRV['is_cosmic'].append(noise['is_cosmic']).to_numpy()
fpr, tpr, _ = roc_curve(y_combo, x_combo)

plt.plot(fpr, tpr, linestyle='--', label='without PE')
plt.yscale('log')
plt.ylim(0.9999, 1)
plt.legend()

# %%
nncut=0.2
withCRV.query(cut_extmom+'& lyield==17000 & pred<%f'%nncut)[['is_high', '_z', 'dequal_TrkQual', 'crvinfo__PEs', 'crvinfo__dT']]
# Out:
#          is_high      _z  dequal_TrkQual  crvinfo__PEs  crvinfo__dT
# entry
# 289161         0  3539.2             1.0          86.0        -15.4
# 490458         0 18675.7             1.0         118.0        -56.5
# 316878         0  1266.5             1.0         135.0         -7.6
# 680791         0  5308.3             1.0          98.0        -25.3
# 867836         0  8392.9             1.0         147.0        -36.8
# 1140638        0  4716.6             1.0         103.0        -27.1
# 1329300        0  4476.7             1.0         200.0        -44.1
# 1354408        0  7581.1             1.0         163.0        -52.4
# 151437         1 11961.4             1.0          62.0        -26.1
# 288499         1 12907.4             1.0         282.0        -63.8

# %%
plotted_all = variousYields.query(cut_extmom+'& crvinfo__timeWindowStart>0 & lyield==17000')
plotted = withCRV.query(cut_extmom+'& crvinfo__timeWindowStart>0 & lyield==17000 & pred<%f'%nncut)

plt.hist2d(plotted_all['crvinfomc__z'], plotted_all['crvinfomc__x'], bins=(200,200), norm=matplotlib.colors.LogNorm(), cmap=plt.cm.jet);
plt.colorbar();
plt.title("CRY4 Cosmic Distribution");
plt.xlabel("z [mm]");
plt.ylabel("x [mm]");

plt.plot(plotted['crvinfomc__z'], plotted['crvinfomc__x'], 'ro', label='non-vetoed');
plt.legend()

plt.figure()
plt.hist(plotted['crvinfo__PEs'], bins=range(0,1000,1), histtype='step', label='non-vetoed');
plt.hist(plotted_all['crvinfo__PEs'], bins=range(0,1000,1), histtype='step', label='All');
plt.xlabel('PE')
plt.yscale('log')
plt.legend()

plt.figure()
plt.hist(plotted['crvinfo__dT'], bins=range(-200,200,1), histtype='step', label='non-vetoed');
plt.hist(plotted_all['crvinfo__dT'], bins=range(-200,200,1), histtype='step', label='All');
plt.xlabel('dT [ns]')
plt.yscale('log')
plt.legend()

# %% [markdown]
# #Save CRY4 data

# %%
withCRV.to_hdf(main_path+"root_files_cry4/cr4dfml.hd5", key='df', mode='w')
